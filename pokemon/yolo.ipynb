# %% [markdown]
# # YOLO
# ## Ralphy Núñez Mercado
# ## Reconocimiento de Pokemons con un dataset ya creado + imagenes conseguidas y etiquetadas manualmente por mi.
# ## Tarea:
# La tarea consiste en que elijas una de las posibles tareas en YOLOv11 e implementes un ejemplo.
#
# Crea un dataset personalizado (puedes etiquetarlo por ejemplo en Roboflow)
# Deberás explicar paso a paso el proceso que has seguido además de el por qué de tu elección.

# %% [markdown]
# Para esta tarea he decidido utilizar un dataset ya existente de diferentes pokémon para ahorrar tiempo etiquetando y he hecho scrapping del una pagina con las cartas para tener mas variedad en diseño y pose de los pokémons en el dataset y practicar el labeling con roboflow
#
#
# ![image.png](attachment:image.png)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="7aa465mTTenP1kAdl5UN")
project = rf.workspace("reconocimiento-pokmon").project("pokemon-clb9k-s5mx1")
version = project.version(1)
dataset = version.download("yolov11")
